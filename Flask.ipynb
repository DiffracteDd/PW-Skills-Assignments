# %% [markdown]
# 1>Flask is a web framework, it’s a Python module that lets you develop web applications easily. It’s has a small and easy-to-extend core.
#
#
#     Some of the advantages of flask framework are :
#     1) Scalable
#     2)Flexible
#     3)Lightweight

# %% [markdown]
# 2> ![image.png](attachment:f83e9df8-1898-424c-94b6-f8c5e0faf797.png)

# %% [markdown]
# 3>App routing is used to map the specific URL with the associated function that is intended to perform some task.
#
#     App routing is used to map the specific URL with the associated function that is intended to perform some task. It is used to access some particular page like Flask Tutorial in the web application.

# %% [markdown]
# 4> ![image.png](attachment:0205d9ed-bd1a-4ceb-9aef-5fe959a90149.png)

# %% [markdown]
# 5> We use the route() decorator to bind a function to a URL.

# %% [markdown]
#     from flask import url_for, Flask
#     appFlask = Flask(__name__)
#     @appFlask.route('/home')
#     def home():
#        return 'We are in Home Page!'
#     with appFlask.test_request_context():
#         print(url_for('login'))
